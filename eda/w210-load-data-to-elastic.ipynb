# %% [markdown]
# # Install Packages

# %%
# %matplotlib inline

# %%
# !sudo -H pip install elasticsearch numpy pandas requests xmltodict
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-2.3.0-py2.py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 3.0MB/s
# Requirement already satisfied (use --upgrade to upgrade): numpy in /usr/local/lib/python2.7/dist-packages
# Requirement already satisfied (use --upgrade to upgrade): pandas in /usr/local/lib/python2.7/dist-packages
# Requirement already satisfied (use --upgrade to upgrade): requests in /usr/lib/python2.7/dist-packages
# Collecting xmltodict
#   Downloading xmltodict-0.10.2.tar.gz
# Collecting urllib3<2.0,>=1.8 (from elasticsearch)
#   Downloading urllib3-1.16-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 5.9MB/s
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /usr/local/lib/python2.7/dist-packages (from pandas)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil->pandas)
# Building wheels for collected packages: xmltodict
# done
#   Stored in directory: /root/.cache/pip/wheels/2a/dc/70/da8958d7089d994c8614bc38210f64855f09615e85707bf615
# Successfully built xmltodict
# Installing collected packages: urllib3, elasticsearch, xmltodict
#   Found existing installation: urllib3 1.7.1
#     DEPRECATION: Uninstalling a distutils installed project (urllib3) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling urllib3-1.7.1:
#       Successfully uninstalled urllib3-1.7.1
# Successfully installed elasticsearch-2.3.0 urllib3-1.16 xmltodict-0.10.2

# %%
import codecs
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk
import json
import numpy as np
import os
import pandas as pd
import requests
import xml
import xmltodict

# %% [markdown]
# # Reload the Metadata

# %%
# If we don't have any of the cached data files, download them from S3

if not os.path.isdir('iati'):
    # !aws s3 --region us-west-2 cp s3://mdang.w210/iati.tar.gz .
    # !tar -zxf iati.tar.gz

if not os.path.isfile('metadata.json'):
    # !aws s3 cp s3://mdang.w210/metadata.json.gz .
    # !gunzip metadata.json.gz
# Out:
# download: s3://mdang.w210/iati.tar.gz to ./iati.tar.gz
# download: s3://mdang.w210/metadata.json.gz to ./metadata.json.gz

# %%
with codecs.open('metadata.json', 'r', 'utf-8') as metadata_file:
    metadata = json.load(metadata_file)

# %%
count = len(metadata)
count
# Out:
# 4126

# %% [markdown]
# # Choose a Random Data Set

# %%
# Choose a random data set to explore

random_metadata = None

while random_metadata is None:
    index = np.random.randint(count)
    random_metadata = metadata[index]

    if not random_metadata['isopen']:
        random_metadata = None

random_title = random_metadata['title']
random_short_name = random_metadata['name']

random_iati_filename = 'iati/' + random_short_name + '.xml'

print random_title
print 'http://iatiregistry.org/dataset/%s' % random_short_name
# Out:
# European Union Activity File - Nepal
# http://iatiregistry.org/dataset/ec-devco-np

# %%
random_iati_filename
# Out:
# u'iati/ec-devco-np.xml'

# %% [markdown]
# # Explore the Random Data Set

# %%
# Find out how many activities we have

with open(random_iati_filename, 'rb') as random_iati_file:
    activities_xml = xmltodict.parse(random_iati_file, xml_attribs=True)
    activities = activities_xml['iati-activities']['iati-activity']

print len(activities)
# Out:
# 258

# %%
# Print out one of the activities

print json.dumps(activities[0], indent = 2)
# Out:
# {
#   "@default-currency": "EUR",
#   "@last-updated-datetime": "2016-04-11T15:10:44",
#   "@version": "1.04",
#   "@xml:lang": "en",
#   "@hierarchy": "1",
#   "reporting-org": {
#     "@ref": "XI-IATI-EC_DEVCO",
#     "@type": "15",
#     "#text": "European Commission - Development and Cooperation-EuropeAid"
#   },
#   "iati-identifier": "EU-1-1998/010-887",
#   "title": "COLLEGE PHILOSOPHIQUE DE SHECHEN (SHEDRA) - NEPAL",
#   "description": {
#     "@type": "1",
#     "#text": "Mise en place d'un college destine a l'enseignement de hautniveau des sciences traditionnelles tibetaines,Boudanath,Katmandou"
#   },
#   "activity-status": {
#     "@code": "3",
#     "#text": "Completion"
#   },
#   "activity-date": [
#     {
#       "@iso-date": "1998-07-01",
#       "@type": "start-planned"
#     },
#     {
#       "@iso-date": "1998-07-01",
#       "@type": "start-actual"
#     },
#     {
#       "@iso-date": "2003-06-11",
#       "@type": "end-planned"
#     },
#     {
#       "@iso-date": "2003-06-11",
#       "@type": "end-actual"
#     }
#   ],
#   "contact-info": {
#     "organisation": "EC - EuropeAid Development & Cooperation (DEVCO)",
#     "telephone": "(+32) 02 299 11 11",
#     "email": "http://ec.europa.eu/europeaid/contact/contact_en.htm",
#     "website": "http://ec.europa.eu/europeaid/index_en.htm"
#   },
#   "participating-org": [
#     {
#       "@ref": "XI-IATI-EC_DEVCO",
#       "@role": "Funding",
#       "@type": "15",
#       "#text": "Commission of the European Communities"
#     },
#     {
#       "@ref": "EU-1",
#       "@role": "Extending",
#       "@type": "15",
#       "#text": "Commission of the European Communities"
#     }
#   ],
#   "recipient-country": {
#     "@code": "NP",
#     "#text": "Nepal"
#   },
#   "sector": {
#     "@code": "11330",
#     "@vocabulary": "DAC",
#     "#text": "Vocational training"
#   },
#   "policy-marker": [
#     {
#       "@code": "01",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Gender Equality"
#     },
#     {
#       "@code": "02",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Aid to Environment"
#     },
#     {
#       "@code": "03",
#       "@significance": "2",
#       "@vocabulary": "DAC",
#       "#text": "Participatory Development/Good"
#     },
#     {
#       "@code": "04",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Trade Development"
#     },
#     {
#       "@code": "05",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Aid Targeting the Objectives of the Convention on Biological Diversity"
#     },
#     {
#       "@code": "06",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Aid Targeting the Objectives of the Framework Convention on Climate Change - Mitigation"
#     },
#     {
#       "@code": "07",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Aid Targeting the Objectives of the Framework Convention on Climate Change - Adaptation"
#     },
#     {
#       "@code": "08",
#       "@significance": "0",
#       "@vocabulary": "DAC",
#       "#text": "Aid Targeting the Objectives of the Convention to Combat Desertification"
#     }
#   ],
#   "collaboration-type": {
#     "@code": "1",
#     "#text": "Bilateral"
#   },
#   "default-flow-type": {
#     "@code": "50",
#     "#text": "Other flows"
#   },
#   "default-finance-type": {
#     "@code": "110",
#     "#text": "Grant"
#   },
#   "default-aid-type": {
#     "@code": "NGO",
#     "#text": "Aid through NGOs"
#   },
#   "transaction": [
#     {
#       "@ref": "EU-1-1998/010-887/0",
#       "transaction-date": {
#         "@iso-date": "1999-03-11",
#         "#text": "1999-03-11"
#       },
#       "transaction-type": {
#         "@code": "C",
#         "#text": "Commitments"
#       },
#       "value": {
#         "@value-date": "1999-03-11",
#         "#text": "195446"
#       },
#       "receiver-org": "Fondation Padmasambava"
#     },
#     {
#       "@ref": "EU-1-1998/010-887/3",
#       "transaction-date": {
#         "@iso-date": "2012-03-06",
#         "#text": "2012-03-06"
#       },
#       "transaction-type": {
#         "@code": "C",
#         "#text": "Commitments"
#       },
#       "value": {
#         "@value-date": "2012-03-06",
#         "#text": "-6363"
#       },
#       "receiver-org": "Fondation Padmasambava"
#     }
#   ],
#   "activity-website": "http://ec.europa.eu/europeaid/index_en.htm"
# }

# %% [markdown]
# # Add Random Data Set to Elasticsearch

# %% [markdown]
# Following the Elasticsearch DSL Python tutorial for the following.
#
# * http://elasticsearch-dsl.readthedocs.io/en/latest/

# %%
# Create an Elasticsearch connection

connections.create_connection(hosts = ['localhost'])

es = Elasticsearch()

# %%
for activity in activities:
    document_id = '%s.%s' % (random_short_name, activity['iati-identifier'])
    print document_id

    try:
        es.index(index = 'iati-activities', doc_type = 'iatiactivity', id = document_id, body = activity)
    except:
        print 'Failed to add'
# Out:
# ec-devco-np.EU-1-1998/010-887
# ec-devco-np.EU-1-2000/2589/0
# Failed to add directly
# ec-devco-np.EU-1-2004/064-096
# ec-devco-np.EU-1-2004/16751/0
# Failed to add directly
# ec-devco-np.EU-1-2005/094-675
# ec-devco-np.EU-1-2005/095-157
# ec-devco-np.EU-1-2005/095-462
# ec-devco-np.EU-1-2005/103-144
# ec-devco-np.EU-1-2005/110-999
# ec-devco-np.EU-1-2005/112-787
# ec-devco-np.EU-1-2005/112-979
# ec-devco-np.EU-1-2005/17237/0
# ec-devco-np.EU-1-2005/17635/0
# Failed to add directly
# ec-devco-np.EU-1-2006/118-620
# ec-devco-np.EU-1-2006/118-644
# ec-devco-np.EU-1-2006/118-883
# ec-devco-np.EU-1-2006/119-337
# ec-devco-np.EU-1-2006/119-627
# ec-devco-np.EU-1-2006/126-070
# ec-devco-np.EU-1-2006/126-110
# ec-devco-np.EU-1-2006/126-183
# ec-devco-np.EU-1-2006/129-635
# ec-devco-np.EU-1-2006/18408/0
# Failed to add directly
# ec-devco-np.EU-1-2006/18441/0
# Failed to add directly
# ec-devco-np.EU-1-2007/133-412
# ec-devco-np.EU-1-2007/133-415
# ec-devco-np.EU-1-2007/133-430
# ec-devco-np.EU-1-2007/133-443
# ec-devco-np.EU-1-2007/133-463
# ec-devco-np.EU-1-2007/133-554
# ec-devco-np.EU-1-2007/133-557
# ec-devco-np.EU-1-2007/137-168
# ec-devco-np.EU-1-2007/137-233
# ec-devco-np.EU-1-2007/137-261
# ec-devco-np.EU-1-2007/137-275
# ec-devco-np.EU-1-2007/138-946
# ec-devco-np.EU-1-2007/141-142
# ec-devco-np.EU-1-2007/141-337
# ec-devco-np.EU-1-2007/141-953
# ec-devco-np.EU-1-2007/141-983
# ec-devco-np.EU-1-2007/142-041
# ec-devco-np.EU-1-2007/142-042
# ec-devco-np.EU-1-2007/142-051
# ec-devco-np.EU-1-2007/142-054
# ec-devco-np.EU-1-2007/142-065
# ec-devco-np.EU-1-2007/142-084
# ec-devco-np.EU-1-2007/19109/0
# Failed to add directly
# ec-devco-np.EU-1-2007/19265/0
# Failed to add directly
# ec-devco-np.EU-1-2008/148-079
# ec-devco-np.EU-1-2008/152-937
# ec-devco-np.EU-1-2008/153-257
# ec-devco-np.EU-1-2008/158-049
# ec-devco-np.EU-1-2008/158-067
# ec-devco-np.EU-1-2008/158-158
# ec-devco-np.EU-1-2008/158-218
# ec-devco-np.EU-1-2008/158-394
# ec-devco-np.EU-1-2008/158-400
# ec-devco-np.EU-1-2008/159-300
# ec-devco-np.EU-1-2008/160-539
# ec-devco-np.EU-1-2008/161-779
# ec-devco-np.EU-1-2008/161-787
# ec-devco-np.EU-1-2008/161-789
# ec-devco-np.EU-1-2008/161-797
# ec-devco-np.EU-1-2008/161-832
# ec-devco-np.EU-1-2008/169-990
# ec-devco-np.EU-1-2008/170-101
# ec-devco-np.EU-1-2008/170-102
# ec-devco-np.EU-1-2008/170-457
# ec-devco-np.EU-1-2008/172-426
# ec-devco-np.EU-1-2009/154-908
# ec-devco-np.EU-1-2009/158-139
# ec-devco-np.EU-1-2009/158-203
# ec-devco-np.EU-1-2009/158-224
# ec-devco-np.EU-1-2009/158-233
# ec-devco-np.EU-1-2009/158-243
# ec-devco-np.EU-1-2009/204-215
# ec-devco-np.EU-1-2009/206-711
# ec-devco-np.EU-1-2009/207-231
# ec-devco-np.EU-1-2009/21209/0
# Failed to add directly
# ec-devco-np.EU-1-2009/213-101
# ec-devco-np.EU-1-2009/213-223
# ec-devco-np.EU-1-2009/213-741
# ec-devco-np.EU-1-2009/214-167
# ec-devco-np.EU-1-2009/216-441
# ec-devco-np.EU-1-2009/216-469
# ec-devco-np.EU-1-2009/216-472
# ec-devco-np.EU-1-2009/216-475
# ec-devco-np.EU-1-2009/216-481
# ec-devco-np.EU-1-2009/217-758
# ec-devco-np.EU-1-2009/219-038
# ec-devco-np.EU-1-2009/219-432
# ec-devco-np.EU-1-2009/221-894
# ec-devco-np.EU-1-2009/222-051
# ec-devco-np.EU-1-2009/222-053
# ec-devco-np.EU-1-2009/222-351
# ec-devco-np.EU-1-2010/19750/1
# Failed to add directly
# ec-devco-np.EU-1-2010/216-571
# ec-devco-np.EU-1-2010/22504/0
# Failed to add directly
# ec-devco-np.EU-1-2010/228-798
# ec-devco-np.EU-1-2010/228-848
# ec-devco-np.EU-1-2010/229-739
# ec-devco-np.EU-1-2010/230-000
# ec-devco-np.EU-1-2010/230-024
# ec-devco-np.EU-1-2010/231-089
# ec-devco-np.EU-1-2010/234-000
# ec-devco-np.EU-1-2010/234-001
# ec-devco-np.EU-1-2010/234-014
# ec-devco-np.EU-1-2010/234-035
# ec-devco-np.EU-1-2010/234-037
# ec-devco-np.EU-1-2010/234-038
# ec-devco-np.EU-1-2010/234-040
# ec-devco-np.EU-1-2010/234-074
# ec-devco-np.EU-1-2010/234-125
# ec-devco-np.EU-1-2010/234-452
# ec-devco-np.EU-1-2010/240-217
# ec-devco-np.EU-1-2010/245-090
# ec-devco-np.EU-1-2010/246-226
# ec-devco-np.EU-1-2010/246-266
# ec-devco-np.EU-1-2010/248-115
# ec-devco-np.EU-1-2010/248-144
# ec-devco-np.EU-1-2010/248-150
# ec-devco-np.EU-1-2010/248-154
# ec-devco-np.EU-1-2010/248-205
# ec-devco-np.EU-1-2010/249-339
# ec-devco-np.EU-1-2010/250-699
# ec-devco-np.EU-1-2010/259-600
# ec-devco-np.EU-1-2011/22793/0
# Failed to add directly
# ec-devco-np.EU-1-2011/23209/0
# Failed to add directly
# ec-devco-np.EU-1-2011/236-672
# ec-devco-np.EU-1-2011/236-676
# ec-devco-np.EU-1-2011/250-596
# ec-devco-np.EU-1-2011/250-605
# ec-devco-np.EU-1-2011/250-679
# ec-devco-np.EU-1-2011/251-023
# ec-devco-np.EU-1-2011/262-566
# ec-devco-np.EU-1-2011/262-897
# ec-devco-np.EU-1-2011/263-230
# ec-devco-np.EU-1-2011/263-468
# ec-devco-np.EU-1-2011/264-013
# ec-devco-np.EU-1-2011/266-419
# ec-devco-np.EU-1-2011/266-734
# ec-devco-np.EU-1-2011/266-749
# ec-devco-np.EU-1-2011/266-751
# ec-devco-np.EU-1-2011/266-752
# ec-devco-np.EU-1-2011/267-486
# ec-devco-np.EU-1-2011/267-528
# ec-devco-np.EU-1-2011/267-543
# ec-devco-np.EU-1-2011/267-580
# ec-devco-np.EU-1-2011/267-681
# ec-devco-np.EU-1-2011/267-705
# ec-devco-np.EU-1-2011/270-000
# ec-devco-np.EU-1-2011/280-461
# ec-devco-np.EU-1-2011/281-601
# ec-devco-np.EU-1-2011/282-798
# ec-devco-np.EU-1-2011/283-221
# ec-devco-np.EU-1-2012/23402/1
# Failed to add directly
# ec-devco-np.EU-1-2012/23404/0
# Failed to add directly
# ec-devco-np.EU-1-2012/23426/1
# Failed to add directly
# ec-devco-np.EU-1-2012/271-378
# ec-devco-np.EU-1-2012/271-844
# ec-devco-np.EU-1-2012/271-933
# ec-devco-np.EU-1-2012/282-382
# ec-devco-np.EU-1-2012/283-276
# ec-devco-np.EU-1-2012/286-943
# ec-devco-np.EU-1-2012/287-648
# ec-devco-np.EU-1-2012/289-671
# ec-devco-np.EU-1-2012/289-908
# ec-devco-np.EU-1-2012/289-916
# ec-devco-np.EU-1-2012/290-290
# ec-devco-np.EU-1-2012/290-688
# ec-devco-np.EU-1-2012/291-045
# ec-devco-np.EU-1-2012/291-499
# ec-devco-np.EU-1-2012/292-210
# ec-devco-np.EU-1-2012/292-367
# ec-devco-np.EU-1-2012/292-381
# ec-devco-np.EU-1-2012/292-412
# ec-devco-np.EU-1-2012/292-546
# ec-devco-np.EU-1-2012/292-568
# ec-devco-np.EU-1-2012/292-699
# ec-devco-np.EU-1-2012/292-704
# ec-devco-np.EU-1-2012/295-535
# ec-devco-np.EU-1-2012/299-660
# ec-devco-np.EU-1-2012/301-109
# ec-devco-np.EU-1-2012/302-946
# ec-devco-np.EU-1-2012/305-833
# ec-devco-np.EU-1-2012/306-602
# ec-devco-np.EU-1-2012/308-298
# ec-devco-np.EU-1-2012/308-308
# ec-devco-np.EU-1-2012/308-312
# ec-devco-np.EU-1-2012/310-775
# ec-devco-np.EU-1-2013/23283/0
# Failed to add directly
# ec-devco-np.EU-1-2013/311-453
# ec-devco-np.EU-1-2013/311-804
# ec-devco-np.EU-1-2013/312-252
# ec-devco-np.EU-1-2013/312-712
# ec-devco-np.EU-1-2013/315-511
# ec-devco-np.EU-1-2013/315-591
# ec-devco-np.EU-1-2013/315-594
# ec-devco-np.EU-1-2013/315-596
# ec-devco-np.EU-1-2013/320-495
# ec-devco-np.EU-1-2013/322-145
# ec-devco-np.EU-1-2013/323-368
# ec-devco-np.EU-1-2013/333-671
# ec-devco-np.EU-1-2013/334-311
# ec-devco-np.EU-1-2013/334-464
# ec-devco-np.EU-1-2013/335-222
# ec-devco-np.EU-1-2014/30799/0
# Failed to add directly
# ec-devco-np.EU-1-2014/320-826
# ec-devco-np.EU-1-2014/320-943
# ec-devco-np.EU-1-2014/321-035
# ec-devco-np.EU-1-2014/321-036
# ec-devco-np.EU-1-2014/329-764
# ec-devco-np.EU-1-2014/330-493
# ec-devco-np.EU-1-2014/330-496
# ec-devco-np.EU-1-2014/335-585
# ec-devco-np.EU-1-2014/337-140
# ec-devco-np.EU-1-2014/337-378
# ec-devco-np.EU-1-2014/337-636
# ec-devco-np.EU-1-2014/338-793
# ec-devco-np.EU-1-2014/339-168
# ec-devco-np.EU-1-2014/339-174
# ec-devco-np.EU-1-2014/339-776
# ec-devco-np.EU-1-2014/340-011
# ec-devco-np.EU-1-2014/343-685
# ec-devco-np.EU-1-2014/343-946
# ec-devco-np.EU-1-2014/345-498
# ec-devco-np.EU-1-2014/345-844
# ec-devco-np.EU-1-2014/345-929
# ec-devco-np.EU-1-2014/348-189
# ec-devco-np.EU-1-2014/348-665
# ec-devco-np.EU-1-2014/348-722
# ec-devco-np.EU-1-2014/349-144
# ec-devco-np.EU-1-2014/349-276
# ec-devco-np.EU-1-2014/349-953
# ec-devco-np.EU-1-2014/351-752
# ec-devco-np.EU-1-2014/352-624
# ec-devco-np.EU-1-2014/353-245
# ec-devco-np.EU-1-2014/354-105
# ec-devco-np.EU-1-2014/355-375
# ec-devco-np.EU-1-2015/357-774
# ec-devco-np.EU-1-2015/357-900
# ec-devco-np.EU-1-2015/358-296
# ec-devco-np.EU-1-2015/358-823
# ec-devco-np.EU-1-2015/358-824
# ec-devco-np.EU-1-2015/358-825
# ec-devco-np.EU-1-2015/359-386
# ec-devco-np.EU-1-2015/359-535
# ec-devco-np.EU-1-2015/360-969
# ec-devco-np.EU-1-2015/364-980
# ec-devco-np.EU-1-2015/370-970
# ec-devco-np.EU-1-2015/371-179
# ec-devco-np.EU-1-2015/371-308
# ec-devco-np.EU-1-2015/371-553
# ec-devco-np.EU-1-2015/371-706
# ec-devco-np.EU-1-2015/371-709
# ec-devco-np.EU-1-2015/372-059
# ec-devco-np.EU-1-2015/372-247
# ec-devco-np.EU-1-2016/372-416

# %% [markdown]
# Now we can check Elasticsearch and see what the index looks like.

# %%
# !echo http://$(curl -s http://169.254.169.254/latest/meta-data/public-hostname):5601/
# Out:
# http://ec2-54-149-233-245.us-west-2.compute.amazonaws.com:5601/

# %% [markdown]
# As an example of EDA that's possible using Elasticsearch and Kibana, you can look into the values on the description by doing the following:
#
# 1. Navigate to the Discover tab.
# 2. Select the gear icon to change the Available Fields to only included indexed fields (for visualization)
# 3. As an example, check the description.#text field

# %% [markdown]
# # Add All Data to Elasticsearch

# %%
# Choose a random data set to explore

success = 0
failure = 0
processed = 0

for metadata_item in metadata:
    title = metadata_item['title']
    short_name = metadata_item['name']

    # Progress update every 100 XML files so that we know the process
    # is actually still processing its 4000 files.

    processed += 1

    if processed % 100 == 0:
        print 'Processed', processed, 'of', count, 'files'

    iati_filename = 'iati/' + short_name + '.xml'

    # If the data set is not open or we have other errors, we won't
    # have a data file to work with.

    if not os.path.isfile(iati_filename):
        continue

    # Extract the activities from the XML as a dictionary

    activities = []

    had_xml_error = False

    with open(iati_filename, 'rb') as iati_file:
        try:
            activities_xml = xmltodict.parse(iati_file, xml_attribs=True)

            root_item = activities_xml['iati-activities']

            if 'iati-activity' in root_item:
                activities = root_item['iati-activity']
        except:
            had_xml_error = True

    # Build up the set of bulk actions for this specific XML file

    bulk_actions = []

    for activity in activities:
        try:
            document_id = '%s.%s' % (random_short_name, activity['iati-identifier'])
            bulk_actions.append({
                '_index': 'iati-activities',
                '_type': 'iatiactivity',
                '_id': document_id,
                'doc': activity
            })
        except:
            had_xml_error = True

    # Insert the documents in bulk and report if we receive any errors

    result = bulk(es, bulk_actions, stats_only = True, raise_on_error = False)

    if had_xml_error:
        print 'XML handling error processing', short_name

    if result[1] != 0:
        print result[1], 'elasticsearch errors processing',  short_name
# Out:
# 1856 elasticsearch errors processing sdc_ch-140402
# 2097 elasticsearch errors processing sdc_ch-150410
# 3446 elasticsearch errors processing sdc_ch-160408
# 68 elasticsearch errors processing ia_nam-o100
# XML handling error processing acord-cd
# XML handling error processing acord-tz
# 208 elasticsearch errors processing ia_nam-o29
# 2 elasticsearch errors processing addinternational-289
# 4 elasticsearch errors processing addinternational-298
# 2 elasticsearch errors processing addinternational-798
# XML handling error processing addinternational-998
# 6 elasticsearch errors processing addinternational-activities
# 2 elasticsearch errors processing addinternational-bd
# 2 elasticsearch errors processing addinternational-bf
# 4 elasticsearch errors processing addinternational-gb
# XML handling error processing addinternational-in
# XML handling error processing addinternational-kh
# XML handling error processing addinternational-sd
# XML handling error processing addinternational-tz
# XML handling error processing addinternational-ug
# 4 elasticsearch errors processing adrauk-activities
# XML handling error processing anda-gec
# 173 elasticsearch errors processing aauk-appeals2014
# 3 elasticsearch errors processing apt-ke
# XML handling error processing apt-ug
# XML handling error processing ark-activities
# XML handling error processing abaseen-activities
# XML handling error processing unw-1052
# XML handling error processing across-activity
# XML handling error processing across-ss
# 154 elasticsearch errors processing ia_nam-o2
# 7 elasticsearch errors processing ia_nam-o3
# XML handling error processing aauk-activities
# 468 elasticsearch errors processing scuk-zz
# 183 elasticsearch errors processing scuk-archive
# 115 elasticsearch errors processing self-help-africa-092014
# 237 elasticsearch errors processing pa-activities
# XML handling error processing aai-998
# XML handling error processing aai-in
# XML handling error processing aai-mm
# XML handling error processing aai-ng
# XML handling error processing aai-np
# XML handling error processing aai-tz
# XML handling error processing aai-ug
# XML handling error processing aai-vn
# XML handling error processing lead_international-activities
# XML handling error processing pont-activities
# 5 elasticsearch errors processing progressio-activities
# XML handling error processing tao-03473165-activities
# XML handling error processing wsup-activities
# 9 elasticsearch errors processing iucn_nl-2016q1act
# 98 elasticsearch errors processing rainfoundation-a0
# XML handling error processing transparency-international-1_0931_2
# XML handling error processing transparency-international-1_0931_3
# XML handling error processing transparency-international-1_0931_4
# Processed 100 of 4126 files
# XML handling error processing transparency-international-1_0287
# XML handling error processing transparency-international-1_0744
# XML handling error processing transparency-international-1_0758
# XML handling error processing transparency-international-10792
# XML handling error processing transparency-international-1_0794
# XML handling error processing transparency-international-1_0893
# XML handling error processing transparency-international-1_0931
# XML handling error processing transparency-international-1_0941
# XML handling error processing transparency-international-1_0996
# XML handling error processing transparency-international-1_1001
# XML handling error processing transparency-international-11003
# XML handling error processing transparency-international-1_1010
# XML handling error processing transparency-international-1_1045
# XML handling error processing transparency-international-11053
# XML handling error processing transparency-international-11068
# XML handling error processing transparency-international-1_1073
# XML handling error processing transparency-international-1_1100
# XML handling error processing transparency-international-1_1106
# XML handling error processing transparency-international-12001
# XML handling error processing transparency-international-1_2004
# XML handling error processing transparency-international-1_2007
# XML handling error processing transparency-international-1_2008
# XML handling error processing transparency-international-1_2010
# XML handling error processing transparency-international-1_2012
# XML handling error processing transparency-international-1_2015
# XML handling error processing transparency-international-1_2016
# XML handling error processing transparency-international-1_2017
# XML handling error processing transparency-international-1_2019
# XML handling error processing transparency-international-1_2020
# XML handling error processing transparency-international-1_2021
# XML handling error processing transparency-international-1_2025
# XML handling error processing transparency-international-1_2027
# XML handling error processing transparency-international-1_2029
# XML handling error processing transparency-international-10000000
# XML handling error processing transparency-international-10000287
# XML handling error processing transparency-international-10000318
# XML handling error processing transparency-international-10000345
# XML handling error processing transparency-international-10000383
# XML handling error processing transparency-international-100007633
# XML handling error processing transparency-international-100007631
# XML handling error processing transparency-international-100007632
# XML handling error processing transparency-international-10000839
# XML handling error processing transparency-international-10000848
# XML handling error processing transparency-international-10000913
# 7 elasticsearch errors processing asi-activities
# 12 elasticsearch errors processing ia_nam-o118
# 276 elasticsearch errors processing ia_nam-o4
# 2 elasticsearch errors processing afghanaid-activities
# 283 elasticsearch errors processing ocha_fts-afghanistan_2012
# 180 elasticsearch errors processing ocha_fts-afghanistan_2013
# 168 elasticsearch errors processing ocha_fts-afghanistan_2014
# 157 elasticsearch errors processing ocha_fts-afghanistan_2015
# XML handling error processing acaa-af
# 1580 elasticsearch errors processing aiddata-afghanistanaims
# 3 elasticsearch errors processing afrikids-activities
# 2 elasticsearch errors processing aet-activities
# 2 elasticsearch errors processing nl-kvk-41207989-nl1
# 8 elasticsearch errors processing nl-kvk-41207989-nl2
# 49 elasticsearch errors processing akvo-activities
# 41 elasticsearch errors processing afdb-algeria
# 20 elasticsearch errors processing ia_nam-o5
# XML handling error processing allwecan-cm
# XML handling error processing allwecan-ug
# 24 elasticsearch errors processing ia_nam-o11
# 6 elasticsearch errors processing ia_nam-o6
# 33 elasticsearch errors processing ia_nam-o7
# 616 elasticsearch errors processing ia_nam-o8
# 168 elasticsearch errors processing ia_nam-o9
# 39 elasticsearch errors processing ia_nam-o10
# 20 elasticsearch errors processing ia_nam-o161
# 10 elasticsearch errors processing ia_nam-o131
# 3 elasticsearch errors processing amnesty-1
# 25 elasticsearch errors processing ia_nam-o95
# 2 elasticsearch errors processing amrefha-et
# 10 elasticsearch errors processing ia_nam-o13
# 32 elasticsearch errors processing afdb-angola
# Processed 200 of 4126 files
# 412 elasticsearch errors processing aauk-ukappeals2013
# 2 elasticsearch errors processing art19-activities
# 26 elasticsearch errors processing asdb-af
# 16 elasticsearch errors processing asdb-am
# 13 elasticsearch errors processing asdb-az
# 89 elasticsearch errors processing asdb-bd
# 25 elasticsearch errors processing asdb-bt
# 62 elasticsearch errors processing asdb-kh
# 6 elasticsearch errors processing asdb-ck
# 2 elasticsearch errors processing asdb-fm
# 4 elasticsearch errors processing asdb-fj
# 25 elasticsearch errors processing asdb-ge
# 112 elasticsearch errors processing asdb-in
# 46 elasticsearch errors processing asdb-id
# 14 elasticsearch errors processing asdb-kz
# 3 elasticsearch errors processing asdb-ki
# 38 elasticsearch errors processing asdb-kg
# 51 elasticsearch errors processing asdb-la
# 3 elasticsearch errors processing asdb-mh
# 36 elasticsearch errors processing asdb-mn
# 3 elasticsearch errors processing asdb-mm
# 3 elasticsearch errors processing asdb-nr
# 61 elasticsearch errors processing asdb-np
# 72 elasticsearch errors processing asdb-pk
# 4 elasticsearch errors processing asdb-pw
# 26 elasticsearch errors processing asdb-pg
# 110 elasticsearch errors processing asdb-cn
# 27 elasticsearch errors processing asdb-ph
# 3 elasticsearch errors processing asdb-reg
# 7 elasticsearch errors processing asdb-mv
# 13 elasticsearch errors processing asdb-ws
# 14 elasticsearch errors processing asdb-sb
# 54 elasticsearch errors processing asdb-lk
# 26 elasticsearch errors processing asdb-tj
# 2 elasticsearch errors processing asdb-th
# 10 elasticsearch errors processing asdb-tl
# 8 elasticsearch errors processing asdb-to
# XML handling error processing asdb-tm
# 4 elasticsearch errors processing asdb-tv
# 36 elasticsearch errors processing asdb-uz
# 7 elasticsearch errors processing asdb-vu
# 98 elasticsearch errors processing asdb-vn
# 3 elasticsearch errors processing arfh-activities
# 3 elasticsearch errors processing atosuk-activities
# 144 elasticsearch errors processing ausgov-af
# 6 elasticsearch errors processing ausgov-al
# 5 elasticsearch errors processing ausgov-dz
# 11 elasticsearch errors processing ausgov-ao
# 10 elasticsearch errors processing ausgov-ag
# 40 elasticsearch errors processing ausgov-ar
# 5 elasticsearch errors processing ausgov-az
# 152 elasticsearch errors processing ausgov-bd
# 3 elasticsearch errors processing ausgov-bb
# 18 elasticsearch errors processing ausgov-bz
# 11 elasticsearch errors processing ausgov-bj
# 47 elasticsearch errors processing ausgov-bt
# 17 elasticsearch errors processing ausgov-bo
# 6 elasticsearch errors processing ausgov-ba
# 38 elasticsearch errors processing ausgov-bw
# 57 elasticsearch errors processing ausgov-br
# 19 elasticsearch errors processing ausgov-bf
# 31 elasticsearch errors processing ausgov-bi
# 221 elasticsearch errors processing ausgov-kh
# 27 elasticsearch errors processing ausgov-cm
# 16 elasticsearch errors processing ausgov-cv
# 16 elasticsearch errors processing ausgov-cf
# 14 elasticsearch errors processing ausgov-td
# 47 elasticsearch errors processing ausgov-cl
# 295 elasticsearch errors processing ausgov-cn
# 33 elasticsearch errors processing ausgov-co
# 14 elasticsearch errors processing ausgov-km
# 9 elasticsearch errors processing ausgov-cg
# 52 elasticsearch errors processing ausgov-ck
# 16 elasticsearch errors processing ausgov-cr
# 18 elasticsearch errors processing ausgov-ci
# 7 elasticsearch errors processing ausgov-cu
# 20 elasticsearch errors processing ausgov-kp
# 38 elasticsearch errors processing ausgov-cd
# 9 elasticsearch errors processing ausgov-dj
# 19 elasticsearch errors processing ausgov-dm
# 15 elasticsearch errors processing ausgov-do
# 18 elasticsearch errors processing ausgov-ec
# 34 elasticsearch errors processing ausgov-eg
# 18 elasticsearch errors processing ausgov-sv
# 6 elasticsearch errors processing ausgov-gq
# 6 elasticsearch errors processing ausgov-er
# 70 elasticsearch errors processing ausgov-et
# 230 elasticsearch errors processing ausgov-fj
# 7 elasticsearch errors processing ausgov-ga
# 13 elasticsearch errors processing ausgov-gm
# 4 elasticsearch errors processing ausgov-ge
# 57 elasticsearch errors processing ausgov-gh
# 17 elasticsearch errors processing ausgov-gd
# 21 elasticsearch errors processing ausgov-gt
# 12 elasticsearch errors processing ausgov-gn
# Processed 300 of 4126 files
# 7 elasticsearch errors processing ausgov-gw
# 17 elasticsearch errors processing ausgov-gy
# 31 elasticsearch errors processing ausgov-ht
# 17 elasticsearch errors processing ausgov-hn
# 268 elasticsearch errors processing ausgov-in
# 567 elasticsearch errors processing ausgov-id
# 19 elasticsearch errors processing ausgov-ir
# 52 elasticsearch errors processing ausgov-iq
# 17 elasticsearch errors processing ausgov-jm
# 40 elasticsearch errors processing ausgov-jo
# 4 elasticsearch errors processing ausgov-kz
# 92 elasticsearch errors processing ausgov-ke
# 135 elasticsearch errors processing ausgov-ki
# 6 elasticsearch errors processing ausgov-kg
# 215 elasticsearch errors processing ausgov-la
# 41 elasticsearch errors processing ausgov-lb
# 36 elasticsearch errors processing ausgov-ls
# 29 elasticsearch errors processing ausgov-lr
# 10 elasticsearch errors processing ausgov-ly
# 6 elasticsearch errors processing ausgov-mk
# 19 elasticsearch errors processing ausgov-mg
# 71 elasticsearch errors processing ausgov-mw
# 179 elasticsearch errors processing ausgov-my
# 50 elasticsearch errors processing ausgov-mv
# 19 elasticsearch errors processing ausgov-ml
# 88 elasticsearch errors processing ausgov-mh
# 10 elasticsearch errors processing ausgov-mr
# 29 elasticsearch errors processing ausgov-mu
# 38 elasticsearch errors processing ausgov-mx
# 76 elasticsearch errors processing ausgov-fm
# XML handling error processing ausgov-md
# 69 elasticsearch errors processing ausgov-mn
# 7 elasticsearch errors processing ausgov-me
# 11 elasticsearch errors processing ausgov-ma
# 56 elasticsearch errors processing ausgov-mz
# 182 elasticsearch errors processing ausgov-mm
# 31 elasticsearch errors processing ausgov-na
# 81 elasticsearch errors processing ausgov-nr
# 116 elasticsearch errors processing ausgov-np
# 21 elasticsearch errors processing ausgov-ni
# 23 elasticsearch errors processing ausgov-ne
# 33 elasticsearch errors processing ausgov-ng
# 41 elasticsearch errors processing ausgov-nu
# 57 elasticsearch errors processing ausgov-ps
# 150 elasticsearch errors processing ausgov-pk
# 85 elasticsearch errors processing ausgov-pw
# 12 elasticsearch errors processing ausgov-pa
# 402 elasticsearch errors processing ausgov-pg
# 21 elasticsearch errors processing ausgov-py
# 45 elasticsearch errors processing ausgov-pe
# 297 elasticsearch errors processing ausgov-ph
# 34 elasticsearch errors processing ausgov-rw
# 14 elasticsearch errors processing ausgov-lc
# 17 elasticsearch errors processing ausgov-vc
# 181 elasticsearch errors processing ausgov-ws
# 12 elasticsearch errors processing ausgov-st
# 19 elasticsearch errors processing ausgov-sn
# 10 elasticsearch errors processing ausgov-rs
# 20 elasticsearch errors processing ausgov-sc
# 25 elasticsearch errors processing ausgov-sl
# 255 elasticsearch errors processing ausgov-sb
# 34 elasticsearch errors processing ausgov-so
# 70 elasticsearch errors processing ausgov-za
# 129 elasticsearch errors processing ausgov-lk
# 14 elasticsearch errors processing ausgov-kn
# 38 elasticsearch errors processing ausgov-sd
# 15 elasticsearch errors processing ausgov-sr
# 32 elasticsearch errors processing ausgov-sz
# 21 elasticsearch errors processing ausgov-sy
# 6 elasticsearch errors processing ausgov-tj
# 78 elasticsearch errors processing ausgov-tz
# 283 elasticsearch errors processing ausgov-th
# 178 elasticsearch errors processing ausgov-tl
# 16 elasticsearch errors processing ausgov-tg
# 12 elasticsearch errors processing ausgov-tk
# 180 elasticsearch errors processing ausgov-to
# 6 elasticsearch errors processing ausgov-tt
# 11 elasticsearch errors processing ausgov-tn
# 21 elasticsearch errors processing ausgov-tr
# 86 elasticsearch errors processing ausgov-tv
# 70 elasticsearch errors processing ausgov-ug
# 10 elasticsearch errors processing ausgov-ua
# 16 elasticsearch errors processing ausgov-uy
# XML handling error processing ausgov-uz
# 194 elasticsearch errors processing ausgov-vu
# 10 elasticsearch errors processing ausgov-ve
# 300 elasticsearch errors processing ausgov-vn
# 13 elasticsearch errors processing ausgov-wf
# 17 elasticsearch errors processing ausgov-ye
# 47 elasticsearch errors processing ausgov-zm
# 64 elasticsearch errors processing ausgov-zw
# 72 elasticsearch errors processing ausgov-298
# 165 elasticsearch errors processing ausgov-798
# 6 elasticsearch errors processing ausgov-89
# 74 elasticsearch errors processing ausgov-789
# XML handling error processing ausgov-998
# 34 elasticsearch errors processing ausgov-589
# 10 elasticsearch errors processing ausgov-389
# XML handling error processing ausgov-189
# XML handling error processing ausgov-889
# Processed 400 of 4126 files
# 89 elasticsearch errors processing ausgov-489
# 54 elasticsearch errors processing ausgov-689
# 45 elasticsearch errors processing ausgov-289
# XML handling error processing ausgov-88
# 20 elasticsearch errors processing ausgov-380
# 11 elasticsearch errors processing ia_nam-o16
# 12 elasticsearch errors processing bracintl-activities
# 30 elasticsearch errors processing gb-chc-220949-activities
# XML handling error processing irc_uk-df084
# 7 elasticsearch errors processing ia_nam-o15
# XML handling error processing beesfordevelopment-et
# 78 elasticsearch errors processing afdb-benin
# 11 elasticsearch errors processing ia_nam-o125
# XML handling error processing nrc-9184472
# 3 elasticsearch errors processing bioclimate-activities
# XML handling error processing blueventures-activities
# 7 elasticsearch errors processing bond-activities
# 2 elasticsearch errors processing bothends-298
# 2 elasticsearch errors processing bothends-498
# 2 elasticsearch errors processing bothends-798
# 5 elasticsearch errors processing bothends-998
# XML handling error processing bothends-nl
# 46 elasticsearch errors processing afdb-botswana
# 48 elasticsearch errors processing ia_nam-o17
# 25 elasticsearch errors processing ia_nam-o18
# XML handling error processing buildafrica-ug
# 85 elasticsearch errors processing afdb-burkinafaso
# 114 elasticsearch errors processing ocha_fts-burkina_faso_2012
# 109 elasticsearch errors processing ocha_fts-burkina_faso_2013
# 95 elasticsearch errors processing ocha_fts-burkina_faso_2014
# 82 elasticsearch errors processing ocha_fts-burkina_faso_2015
# 76 elasticsearch errors processing afdb-burundi
# 2 elasticsearch errors processing cafod-afghanistan
# 7 elasticsearch errors processing cafod-africageneral
# 9 elasticsearch errors processing cafod-asiageneral
# 32 elasticsearch errors processing cafod-bangladesh
# XML handling error processing cafod-benin
# 24 elasticsearch errors processing cafod-bolivia
# 61 elasticsearch errors processing cafod-brazil
# XML handling error processing cafod-burma
# 9 elasticsearch errors processing cafod-burundi
# 26 elasticsearch errors processing cafod-cambodia
# 2 elasticsearch errors processing cafod-centralafricanrepublic
# 10 elasticsearch errors processing cafod-centralamerica
# XML handling error processing cafod-chad
# 2 elasticsearch errors processing cafod-chile
# 24 elasticsearch errors processing cafod-colombia
# 153 elasticsearch errors processing cafod-democraticrepublicofcongo
# 17 elasticsearch errors processing cafod-easttimor
# XML handling error processing cafod-egypt
# 11 elasticsearch errors processing cafod-elsalvador
# 7 elasticsearch errors processing cafod-eritrea
# 70 elasticsearch errors processing cafod-ethiopia
# 11 elasticsearch errors processing cafod-generaleastafrica
# 3 elasticsearch errors processing cafod-generalsouthernafrica
# 6 elasticsearch errors processing cafod-generalwestafrica
# 17 elasticsearch errors processing cafod-guatemala
# XML handling error processing cafod-guinea
# XML handling error processing cafod-guyana
# 22 elasticsearch errors processing cafod-haiti
# 8 elasticsearch errors processing cafod-honduras
# XML handling error processing cafod-india
# 16 elasticsearch errors processing cafod-indonesia
# 5 elasticsearch errors processing cafod-israel
# XML handling error processing cafod-jordan
# 121 elasticsearch errors processing cafod-kenya
# XML handling error processing cafod-kyrgyzstan
# 29 elasticsearch errors processing cafod-latinamericageneral
# 6 elasticsearch errors processing cafod-lebanon
# 24 elasticsearch errors processing cafod-liberia
# 15 elasticsearch errors processing cafod-malawi
# XML handling error processing cafod-mali
# Processed 500 of 4126 files
# XML handling error processing cafod-mauritania
# 5 elasticsearch errors processing cafod-mexico
# XML handling error processing cafod-middleeastgeneral
# 75 elasticsearch errors processing cafod-mozambique
# XML handling error processing cafod-multiple
# 4 elasticsearch errors processing cafod-myanmar
# XML handling error processing cafod-namibia
# XML handling error processing cafod-nepal
# 16 elasticsearch errors processing cafod-nicaragua
# 33 elasticsearch errors processing cafod-niger
# 49 elasticsearch errors processing cafod-nigeria
# 14 elasticsearch errors processing cafod-pakistan
# 9 elasticsearch errors processing cafod-palestineopt
# 5 elasticsearch errors processing cafod-paraguay
# 22 elasticsearch errors processing cafod-peru
# 32 elasticsearch errors processing cafod-philippines
# 25 elasticsearch errors processing cafod-rwanda
# 46 elasticsearch errors processing cafod-sierraleone
# 9 elasticsearch errors processing cafod-southafrica
# 71 elasticsearch errors processing cafod-southsudan
# 22 elasticsearch errors processing cafod-srilanka
# 47 elasticsearch errors processing cafod-sudan
# 7 elasticsearch errors processing cafod-swaziland
# 13 elasticsearch errors processing cafod-tanzania
# 2 elasticsearch errors processing cafod-thailand
# 34 elasticsearch errors processing cafod-uganda
# 3 elasticsearch errors processing cafod-westbankjordan
# 47 elasticsearch errors processing cafod-zambia
# 157 elasticsearch errors processing cafod-zimbabwe
# 356 elasticsearch errors processing ia_nam-o19
# XML handling error processing ciuk-0001
# XML handling error processing ciuk-0316
# 9 elasticsearch errors processing ia_nam-o22
# 87 elasticsearch errors processing cdc-activity2012
# 109 elasticsearch errors processing cdc-998
# XML handling error processing cdc-activity
# XML handling error processing ciks-activities
# 1268 elasticsearch errors processing cerf-projectsfundedtodate
# 12 elasticsearch errors processing cfyas-activities
# XML handling error processing cif-am
# 7 elasticsearch errors processing cif-bd
# 2 elasticsearch errors processing cif-bo
# 6 elasticsearch errors processing cif-br
# 3 elasticsearch errors processing cif-bf
# 10 elasticsearch errors processing cif-kh
# 7 elasticsearch errors processing cif-cl
# 9 elasticsearch errors processing cif-co
# 3 elasticsearch errors processing cif-cd
# XML handling error processing cif-dm
# XML handling error processing cif-eg
# 3 elasticsearch errors processing cif-et
# 2 elasticsearch errors processing cif-gh
# 2 elasticsearch errors processing cif-gd
# 4 elasticsearch errors processing cif-ht
# 6 elasticsearch errors processing cif-hn
# 6 elasticsearch errors processing cif-in
# 6 elasticsearch errors processing cif-id
# 3 elasticsearch errors processing cif-jm
# 7 elasticsearch errors processing cif-kz
# 2 elasticsearch errors processing cif-ke
# 2 elasticsearch errors processing cif-la
# 3 elasticsearch errors processing cif-mv
# 2 elasticsearch errors processing cif-ml
# 13 elasticsearch errors processing cif-mx
# 6 elasticsearch errors processing cif-ma
# 7 elasticsearch errors processing cif-mz
# 8 elasticsearch errors processing cif-np
# 4 elasticsearch errors processing cif-ne
# XML handling error processing cif-ng
# XML handling error processing cif-389
# 2 elasticsearch errors processing cif-889
# XML handling error processing cif-pg
# XML handling error processing cif-pe
# 7 elasticsearch errors processing cif-ph
# XML handling error processing cif-lc
# 2 elasticsearch errors processing cif-vc
# 2 elasticsearch errors processing cif-ws
# 8 elasticsearch errors processing cif-za
# 8 elasticsearch errors processing cif-tj
# XML handling error processing cif-tz
# 3 elasticsearch errors processing cif-th
# XML handling error processing cif-to
# 13 elasticsearch errors processing cif-tr
# 10 elasticsearch errors processing cif-ua
# 6 elasticsearch errors processing cif-vn
# XML handling error processing cif-998
# XML handling error processing cif-ye
# 2 elasticsearch errors processing cif-zm
# XML handling error processing cifal-activities
# XML handling error processing coda-activities
# 148 elasticsearch errors processing aauk-committedgiving2014
# Processed 600 of 4126 files
# 111 elasticsearch errors processing tripleline_crownagents-cscf
# XML handling error processing cuammtrustees-activities
# 75 elasticsearch errors processing afdb-cameroon
# 89 elasticsearch errors processing ocha_fts-cameroon_2014
# 115 elasticsearch errors processing ocha_fts-cameroon_2015
# 2 elasticsearch errors processing camfed-gh
# XML handling error processing camfed-mw
# XML handling error processing camfed-tz
# 2 elasticsearch errors processing camfed-zm
# 2 elasticsearch errors processing camfed-zw
# 1989 elasticsearch errors processing gac-amc-act_4
# 57 elasticsearch errors processing afdb-capeverde
# XML handling error processing cww-activities
# 179 elasticsearch errors processing ia_nam-o20
# XML handling error processing cecily-activities
# 41 elasticsearch errors processing afdb-centralafricanrepublic
# 158 elasticsearch errors processing ocha_fts-car_2012
# 243 elasticsearch errors processing ocha_fts-car_2013
# 433 elasticsearch errors processing ocha_fts-car_2014
# 424 elasticsearch errors processing ocha_fts-central_african_republic_2015
# 73 elasticsearch errors processing afdb-chad
# 153 elasticsearch errors processing ocha_fts-chad_2012
# 165 elasticsearch errors processing ocha_fts-chad_2013
# 192 elasticsearch errors processing ocha_fts-chad_2014
# 157 elasticsearch errors processing ocha_fts-chad_2015
# 11 elasticsearch errors processing ia_nam-o98
# XML handling error processing childhopeuk-br
# XML handling error processing childhopeuk-et
# XML handling error processing childhopeuk-in
# XML handling error processing ced-ug
# 151 elasticsearch errors processing ia_nam-o24
# XML handling error processing ccc-activities
# 693 elasticsearch errors processing aiddata-colombiaaims
# 411 elasticsearch errors processing aauk-ukcommittedgiving2013
# 22 elasticsearch errors processing afdb-comoros
# 2 elasticsearch errors processing cu-activities
# XML handling error processing concernuk-et
# 4 elasticsearch errors processing concernuk-pk
# 2 elasticsearch errors processing concernuk-sl
# XML handling error processing concernuk-tz
# 2 elasticsearch errors processing concernuk-zm
# 126 elasticsearch errors processing ia_nam-o87
# 2 elasticsearch errors processing cr-activities
# 37 elasticsearch errors processing afdb-congo
# 5 elasticsearch errors processing ia_nam-o106
# XML handling error processing cord-bi
# 1418 elasticsearch errors processing cordaid-activities
# 141 elasticsearch errors processing ocha_fts-cotedivoire_2012
# 3 elasticsearch errors processing ocha_fts-cuba_2012
# 63 elasticsearch errors processing afdb-ci
# 11 elasticsearch errors processing dai-e-activities
# Processed 700 of 4126 files
# 7 elasticsearch errors processing aauk-dec2014
# 8 elasticsearch errors processing aauk-dec2013
# 377 elasticsearch errors processing dfid-af
# 791 elasticsearch errors processing dfid-298
# 8 elasticsearch errors processing dfid-al
# 16 elasticsearch errors processing dfid-ao
# 10 elasticsearch errors processing dfid-ac
# 147 elasticsearch errors processing dfid-798
# 388 elasticsearch errors processing dfid-bd
# 2 elasticsearch errors processing dfid-bj
# 48 elasticsearch errors processing dfid-ba
# 15 elasticsearch errors processing dfid-br
# 5 elasticsearch errors processing dfid-bf
# 242 elasticsearch errors processing dfid-mm
# 69 elasticsearch errors processing dfid-bi
# 64 elasticsearch errors processing dfid-kh
# 17 elasticsearch errors processing dfid-cm
# 2 elasticsearch errors processing dfid-cv
# 199 elasticsearch errors processing dfid-380
# 30 elasticsearch errors processing dfid-cf
# 11 elasticsearch errors processing dfid-td
# 3 elasticsearch errors processing dfid-cl
# 98 elasticsearch errors processing dfid-cn
# 2 elasticsearch errors processing dfid-cg
# 286 elasticsearch errors processing dfid-cd
# 2 elasticsearch errors processing dfid-cu
# 4 elasticsearch errors processing dfid-dm
# 2 elasticsearch errors processing dfid-tl
# 3 elasticsearch errors processing dfid-ec
# 13 elasticsearch errors processing dfid-eg
# 15 elasticsearch errors processing dfid-er
# 423 elasticsearch errors processing dfid-et
# 45 elasticsearch errors processing dfid-89
# 2 elasticsearch errors processing dfid-fj
# 2 elasticsearch errors processing dfid-ge
# 296 elasticsearch errors processing dfid-gh
# 5 elasticsearch errors processing dfid-gt
# 2 elasticsearch errors processing dfid-gn
# 24 elasticsearch errors processing dfid-gy
# 54 elasticsearch errors processing dfid-ht
# 2 elasticsearch errors processing dfid-hn
# 346 elasticsearch errors processing dfid-in
# 141 elasticsearch errors processing dfid-id
# 56 elasticsearch errors processing dfid-iq
# 10 elasticsearch errors processing dfid-ci
# 29 elasticsearch errors processing dfid-jm
# 4 elasticsearch errors processing dfid-jp
# 36 elasticsearch errors processing dfid-jo
# 458 elasticsearch errors processing dfid-ke
# 65 elasticsearch errors processing dfid-xk
# 45 elasticsearch errors processing dfid-kg
# 11 elasticsearch errors processing dfid-la
# 50 elasticsearch errors processing dfid-lb
# 22 elasticsearch errors processing dfid-ls
# 57 elasticsearch errors processing dfid-lr
# 75 elasticsearch errors processing dfid-ly
# 7 elasticsearch errors processing dfid-mg
# 355 elasticsearch errors processing dfid-mw
# 2 elasticsearch errors processing dfid-mv
# 10 elasticsearch errors processing dfid-ml
# 2 elasticsearch errors processing dfid-mr
# 78 elasticsearch errors processing dfid-589
# 38 elasticsearch errors processing dfid-md
# 2 elasticsearch errors processing dfid-mn
# 177 elasticsearch errors processing dfid-ms
# 248 elasticsearch errors processing dfid-mz
# 2 elasticsearch errors processing dfid-na
# 318 elasticsearch errors processing dfid-np
# 11 elasticsearch errors processing dfid-ni
# 10 elasticsearch errors processing dfid-ne
# 382 elasticsearch errors processing dfid-ng
# 14 elasticsearch errors processing dfid-189
# 451 elasticsearch errors processing dfid-pk
# 6 elasticsearch errors processing dfid-pg
# 8 elasticsearch errors processing dfid-pe
# 15 elasticsearch errors processing dfid-ph
# 27 elasticsearch errors processing dfid-pn
# 12 elasticsearch errors processing dfid-ru
# 222 elasticsearch errors processing dfid-rw
# 2 elasticsearch errors processing dfid-ws
# 2 elasticsearch errors processing dfid-as
# 6 elasticsearch errors processing dfid-sn
# 31 elasticsearch errors processing dfid-rs
# 407 elasticsearch errors processing dfid-sl
# 4 elasticsearch errors processing dfid-sb
# 323 elasticsearch errors processing dfid-so
# 92 elasticsearch errors processing dfid-za
# 234 elasticsearch errors processing dfid-ss
# 176 elasticsearch errors processing dfid-289
# 48 elasticsearch errors processing dfid-lk
# 164 elasticsearch errors processing dfid-sh
# 2 elasticsearch errors processing dfid-lc
# 250 elasticsearch errors processing dfid-sd
# 106 elasticsearch errors processing dfid-sy
# 109 elasticsearch errors processing dfid-tj
# Processed 800 of 4126 files
# 376 elasticsearch errors processing dfid-tz
# 2 elasticsearch errors processing dfid-th
# 20 elasticsearch errors processing dfid-gm
# 2 elasticsearch errors processing dfid-tg
# 5 elasticsearch errors processing dfid-tn
# 10 elasticsearch errors processing dfid-tr
# 13 elasticsearch errors processing dfid-tc
# 313 elasticsearch errors processing dfid-ug
# 23 elasticsearch errors processing dfid-ua
# 2 elasticsearch errors processing dfid-ae
# 14 elasticsearch errors processing dfid-gb
# 4 elasticsearch errors processing dfid-vu
# 98 elasticsearch errors processing dfid-vn
# 154 elasticsearch errors processing dfid-ps
# 147 elasticsearch errors processing dfid-ye
# 267 elasticsearch errors processing dfid-zm
# 196 elasticsearch errors processing dfid-zw
# 40 elasticsearch errors processing dfid-ta
# 10 elasticsearch errors processing aai-dfidglobal2013
# 1330 elasticsearch errors processing dfid-998_1
# 1251 elasticsearch errors processing dfid-998_2
# 1184 elasticsearch errors processing dfid-998_3
# 880 elasticsearch errors processing dfid-998_4
# 9 elasticsearch errors processing dfid-389
# 5 elasticsearch errors processing dfid-679
# 28 elasticsearch errors processing aai-2014
# 6794 elasticsearch errors processing aiddata-drcamp
# XML handling error processing defra_transparency-activity
# 45 elasticsearch errors processing afdb-drc
# 367 elasticsearch errors processing ocha_fts-drc_2012
# 267 elasticsearch errors processing ocha_fts-drc_2013
# 168 elasticsearch errors processing ocha_fts-drc_2014
# 205 elasticsearch errors processing ocha_fts-democratic_republic_of_the_congo_2015
# 1463 elasticsearch errors processing danida-all_1
# 1463 elasticsearch errors processing danida-all_2
# 1463 elasticsearch errors processing danida-all_3
# 1192 elasticsearch errors processing danida-all_4
# 1463 elasticsearch errors processing danida-all_5
# 1463 elasticsearch errors processing danida-all_6
# 1463 elasticsearch errors processing danida-all_7
# XML handling error processing dwp-activities
# 11 elasticsearch errors processing dthfxx12-activities
# 5 elasticsearch errors processing dapp-activities
# XML handling error processing dapp-mw-activities
# XML handling error processing dapp-mw
# XML handling error processing dipr-998
# 8 elasticsearch errors processing dipr-998
# XML handling error processing diltuk-activities
# XML handling error processing dc-activities
# 1409 elasticsearch errors processing ia_nam-o26
# XML handling error processing ddp-activities
# 44 elasticsearch errors processing afdb-djibouti
# 31 elasticsearch errors processing ocha_fts-djibouti_2012
# 28 elasticsearch errors processing ocha_fts-djibouti_2013
# 32 elasticsearch errors processing ocha_fts-djibouti_2014
# 9 elasticsearch errors processing ia_nam-o169
# 16 elasticsearch errors processing cerf-contributions
# 24 elasticsearch errors processing decp-activities
# 170 elasticsearch errors processing ebrd-activity
# 868 elasticsearch errors processing ec-echo-2012
# 765 elasticsearch errors processing ec-echo-2013
# 718 elasticsearch errors processing ec-echo-2014
# 852 elasticsearch errors processing ec-echo-2015
# 381 elasticsearch errors processing ec-echo-2016
# 2 elasticsearch errors processing emms-activities
# 484 elasticsearch errors processing ocha_fts-ebola_virus_outbreak_2014
# XML handling error processing ia_nam-o89
# 84 elasticsearch errors processing afdb-egypt
# 3 elasticsearch errors processing eiuk-tz
# 4 elasticsearch errors processing ewb_canada-activities
# 175 elasticsearch errors processing ia_nam-o27
# 26 elasticsearch errors processing afdb-equatorialguinea
# 11 elasticsearch errors processing afdb-eritrea
# 102 elasticsearch errors processing afdb-ethiopia
# 226 elasticsearch errors processing ocha_fts-ethiopia_2015
# 3 elasticsearch errors processing ec-near-af
# 5 elasticsearch errors processing ec-near-298
# Processed 900 of 4126 files
# 395 elasticsearch errors processing ec-near-al
# 156 elasticsearch errors processing ec-near-dz
# XML handling error processing ec-near-498
# 120 elasticsearch errors processing ec-near-am
# 2 elasticsearch errors processing ec-near-798
# 90 elasticsearch errors processing ec-near-az
# 80 elasticsearch errors processing ec-near-by
# 112 elasticsearch errors processing ec-near-998
# 367 elasticsearch errors processing ec-near-ba
# 4 elasticsearch errors processing ec-near-619
# 54 elasticsearch errors processing ec-near-hr
# 162 elasticsearch errors processing ec-near-eg
# 623 elasticsearch errors processing ec-near-89
# 222 elasticsearch errors processing ec-near-ge
# 3 elasticsearch errors processing ec-near-is
# 72 elasticsearch errors processing ec-near-il
# 175 elasticsearch errors processing ec-near-jo
# 588 elasticsearch errors processing ec-near-xk
# 225 elasticsearch errors processing ec-near-lb
# 30 elasticsearch errors processing ec-near-ly
# 160 elasticsearch errors processing ec-near-mk
# 53 elasticsearch errors processing ec-near-589
# 127 elasticsearch errors processing ec-near-md
# 329 elasticsearch errors processing ec-near-me
# 145 elasticsearch errors processing ec-near-ma
# 82 elasticsearch errors processing ec-near-189
# 273 elasticsearch errors processing ec-near-ps
# 65 elasticsearch errors processing ec-near-ru
# 628 elasticsearch errors processing ec-near-rs
# 1 elasticsearch errors processing ec-near-689
# 8 elasticsearch errors processing ec-near-88
# 47 elasticsearch errors processing ec-near-sy
# 193 elasticsearch errors processing ec-near-tn
# 94 elasticsearch errors processing ec-near-tr
# 164 elasticsearch errors processing ec-near-ua
# 9 elasticsearch errors processing ec-fpi-af
# 9 elasticsearch errors processing ec-fpi-298
# 2 elasticsearch errors processing ec-fpi-498
# 2 elasticsearch errors processing ec-fpi-bd
# 17 elasticsearch errors processing ec-fpi-998
# 9 elasticsearch errors processing ec-fpi-bo
# 2 elasticsearch errors processing ec-fpi-ba
# 4 elasticsearch errors processing ec-fpi-br
# 4 elasticsearch errors processing ec-fpi-bf
# 4 elasticsearch errors processing ec-fpi-bi
# 1 elasticsearch errors processing ec-fpi-cm
# 17 elasticsearch errors processing ec-fpi-cf
# 5 elasticsearch errors processing ec-fpi-619
# 13 elasticsearch errors processing ec-fpi-td
# 9 elasticsearch errors processing ec-fpi-co
# 13 elasticsearch errors processing ec-fpi-cd
# 11 elasticsearch errors processing ec-fpi-ci
# 3 elasticsearch errors processing ec-fpi-do
# 7 elasticsearch errors processing ec-fpi-eg
# 11 elasticsearch errors processing ec-fpi-sv
# 8 elasticsearch errors processing ec-fpi-et
# 9 elasticsearch errors processing ec-fpi-89
# XML handling error processing ec-fpi-789
# 2 elasticsearch errors processing ec-fpi-fj
# 19 elasticsearch errors processing ec-fpi-ge
# 8 elasticsearch errors processing ec-fpi-gn
# 3 elasticsearch errors processing ec-fpi-gw
# 12 elasticsearch errors processing ec-fpi-ht
# XML handling error processing ec-fpi-hn
# 2 elasticsearch errors processing ec-fpi-in
# 4 elasticsearch errors processing ec-fpi-id
# XML handling error processing ec-fpi-ir
# 7 elasticsearch errors processing ec-fpi-iq
# 4 elasticsearch errors processing ec-fpi-jo
# 2 elasticsearch errors processing ec-fpi-ke
# 1 elasticsearch errors processing ec-fpi-xk
# 19 elasticsearch errors processing ec-fpi-kg
# 17 elasticsearch errors processing ec-fpi-lb
# 2 elasticsearch errors processing ec-fpi-lr
# 13 elasticsearch errors processing ec-fpi-ly
# 4 elasticsearch errors processing ec-fpi-mg
# 9 elasticsearch errors processing ec-fpi-ml
# 1 elasticsearch errors processing ec-fpi-mr
# XML handling error processing ec-fpi-mu
# 3 elasticsearch errors processing ec-fpi-589
# 11 elasticsearch errors processing ec-fpi-mm
# 5 elasticsearch errors processing ec-fpi-np
# 3 elasticsearch errors processing ec-fpi-ni
# 44 elasticsearch errors processing ec-fpi-ne
# 11 elasticsearch errors processing ec-fpi-ng
# 8 elasticsearch errors processing ec-fpi-389
# XML handling error processing ec-fpi-189
# 13 elasticsearch errors processing ec-fpi-pk
# 9 elasticsearch errors processing ec-fpi-ps
# 3 elasticsearch errors processing ec-fpi-pe
# 14 elasticsearch errors processing ec-fpi-ph
# 2 elasticsearch errors processing ec-fpi-sn
# XML handling error processing ec-fpi-sl
# XML handling error processing ec-fpi-sb
# 7 elasticsearch errors processing ec-fpi-so
# 2 elasticsearch errors processing ec-fpi-679
# 7 elasticsearch errors processing ec-fpi-ss
# 5 elasticsearch errors processing ec-fpi-289
# 1 elasticsearch errors processing ec-fpi-lk
# 23 elasticsearch errors processing ec-fpi-sd
# Processed 1000 of 4126 files
# 23 elasticsearch errors processing ec-fpi-sy
# 3 elasticsearch errors processing ec-fpi-tj
# 2 elasticsearch errors processing ec-fpi-th
# 2 elasticsearch errors processing ec-fpi-tl
# 5 elasticsearch errors processing ec-fpi-tg
# 7 elasticsearch errors processing ec-fpi-tn
# 4 elasticsearch errors processing ec-fpi-tr
# 13 elasticsearch errors processing ec-fpi-ua
# XML handling error processing ec-fpi-380
# 19 elasticsearch errors processing ec-fpi-ye
# 4 elasticsearch errors processing ec-fpi-zw
# 578 elasticsearch errors processing ec-devco-af
# 472 elasticsearch errors processing ec-devco-298
# 34 elasticsearch errors processing ec-devco-al
# 66 elasticsearch errors processing ec-devco-dz
# 145 elasticsearch errors processing ec-devco-498
# 321 elasticsearch errors processing ec-devco-ao
# 4 elasticsearch errors processing ec-devco-ai
# 12 elasticsearch errors processing ec-devco-ag
# 137 elasticsearch errors processing ec-devco-ar
# 75 elasticsearch errors processing ec-devco-am
# 12 elasticsearch errors processing ec-devco-aw
# 261 elasticsearch errors processing ec-devco-798
# 11 elasticsearch errors processing ec-devco-az
# 7 elasticsearch errors processing ec-devco-bs
# 428 elasticsearch errors processing ec-devco-bd
# 39 elasticsearch errors processing ec-devco-bb
# 31 elasticsearch errors processing ec-devco-by
# 15 elasticsearch errors processing ec-devco-be
# 141 elasticsearch errors processing ec-devco-bz
# 261 elasticsearch errors processing ec-devco-bj
# 45 elasticsearch errors processing ec-devco-bt
# XML handling error processing ec-devco-998
# 288 elasticsearch errors processing ec-devco-bo
# 56 elasticsearch errors processing ec-devco-ba
# 119 elasticsearch errors processing ec-devco-bw
# 254 elasticsearch errors processing ec-devco-br
# XML handling error processing ec-devco-vg
# 2 elasticsearch errors processing ec-devco-bg
# 406 elasticsearch errors processing ec-devco-bf
# 523 elasticsearch errors processing ec-devco-bi
# 312 elasticsearch errors processing ec-devco-kh
# 581 elasticsearch errors processing ec-devco-cm
# 171 elasticsearch errors processing ec-devco-cv
# XML handling error processing ec-devco-ky
# 320 elasticsearch errors processing ec-devco-cf
# 131 elasticsearch errors processing ec-devco-619
# 694 elasticsearch errors processing ec-devco-td
# 129 elasticsearch errors processing ec-devco-cl
# 217 elasticsearch errors processing ec-devco-cn
# 308 elasticsearch errors processing ec-devco-co
# 135 elasticsearch errors processing ec-devco-km
# 873 elasticsearch errors processing ec-devco-cd
# 289 elasticsearch errors processing ec-devco-cg
# 15 elasticsearch errors processing ec-devco-ck
# 61 elasticsearch errors processing ec-devco-cr
# 513 elasticsearch errors processing ec-devco-ci
# 52 elasticsearch errors processing ec-devco-hr
# 72 elasticsearch errors processing ec-devco-cu
# 2 elasticsearch errors processing ec-devco-cy
# XML handling error processing ec-devco-cz
# XML handling error processing ec-devco-dk
# 117 elasticsearch errors processing ec-devco-dj
# 67 elasticsearch errors processing ec-devco-dm
# 288 elasticsearch errors processing ec-devco-do
# 136 elasticsearch errors processing ec-devco-ec
# 27 elasticsearch errors processing ec-devco-eg
# 136 elasticsearch errors processing ec-devco-sv
# 12 elasticsearch errors processing ec-devco-gq
# 164 elasticsearch errors processing ec-devco-er
# XML handling error processing ec-devco-ee
# 483 elasticsearch errors processing ec-devco-et
# 980 elasticsearch errors processing ec-devco-89
# 3 elasticsearch errors processing ec-devco-fk
# 31 elasticsearch errors processing ec-devco-789
# 91 elasticsearch errors processing ec-devco-fj
# XML handling error processing ec-devco-fi
# 23 elasticsearch errors processing ec-devco-pf
# XML handling error processing ec-devco-tf
# 125 elasticsearch errors processing ec-devco-ga
# 101 elasticsearch errors processing ec-devco-gm
# 92 elasticsearch errors processing ec-devco-ge
# 4 elasticsearch errors processing ec-devco-de
# 368 elasticsearch errors processing ec-devco-gh
# 18 elasticsearch errors processing ec-devco-gl
# 30 elasticsearch errors processing ec-devco-gd
# 252 elasticsearch errors processing ec-devco-gt
# 295 elasticsearch errors processing ec-devco-gn
# 294 elasticsearch errors processing ec-devco-gw
# 128 elasticsearch errors processing ec-devco-gy
# 613 elasticsearch errors processing ec-devco-ht
# 228 elasticsearch errors processing ec-devco-hn
# XML handling error processing ec-devco-hk
# XML handling error processing ec-devco-hu
# 263 elasticsearch errors processing ec-devco-in
# 257 elasticsearch errors processing ec-devco-id
# 17 elasticsearch errors processing ec-devco-ir
# 73 elasticsearch errors processing ec-devco-iq
# XML handling error processing ec-devco-ie
# Processed 1100 of 4126 files
# 3 elasticsearch errors processing ec-devco-il
# 277 elasticsearch errors processing ec-devco-jm
# 49 elasticsearch errors processing ec-devco-jo
# 134 elasticsearch errors processing ec-devco-kz
# 472 elasticsearch errors processing ec-devco-ke
# 39 elasticsearch errors processing ec-devco-ki
# 76 elasticsearch errors processing ec-devco-kp
# 14 elasticsearch errors processing ec-devco-xk
# 193 elasticsearch errors processing ec-devco-kg
# 193 elasticsearch errors processing ec-devco-la
# 2 elasticsearch errors processing ec-devco-lv
# 53 elasticsearch errors processing ec-devco-lb
# 170 elasticsearch errors processing ec-devco-ls
# 191 elasticsearch errors processing ec-devco-lr
# 12 elasticsearch errors processing ec-devco-ly
# 3 elasticsearch errors processing ec-devco-lt
# 3 elasticsearch errors processing ec-devco-lu
# 46 elasticsearch errors processing ec-devco-mk
# 571 elasticsearch errors processing ec-devco-mg
# 500 elasticsearch errors processing ec-devco-mw
# 33 elasticsearch errors processing ec-devco-my
# 10 elasticsearch errors processing ec-devco-mv
# 463 elasticsearch errors processing ec-devco-ml
# XML handling error processing ec-devco-mt
# 12 elasticsearch errors processing ec-devco-mh
# 332 elasticsearch errors processing ec-devco-mr
# 78 elasticsearch errors processing ec-devco-mu
# 26 elasticsearch errors processing ec-devco-yt
# 150 elasticsearch errors processing ec-devco-mx
# 19 elasticsearch errors processing ec-devco-fm
# 26 elasticsearch errors processing ec-devco-589
# 18 elasticsearch errors processing ec-devco-md
# 71 elasticsearch errors processing ec-devco-mn
# 7 elasticsearch errors processing ec-devco-me
# 3 elasticsearch errors processing ec-devco-ms
# 100 elasticsearch errors processing ec-devco-ma
# 453 elasticsearch errors processing ec-devco-mz
# 189 elasticsearch errors processing ec-devco-mm
# 202 elasticsearch errors processing ec-devco-na
# 13 elasticsearch errors processing ec-devco-nr
# 240 elasticsearch errors processing ec-devco-np
# 26 elasticsearch errors processing ec-devco-an
# 16 elasticsearch errors processing ec-devco-nc
# 386 elasticsearch errors processing ec-devco-ni
# 487 elasticsearch errors processing ec-devco-ne
# 360 elasticsearch errors processing ec-devco-ng
# 22 elasticsearch errors processing ec-devco-nu
# 177 elasticsearch errors processing ec-devco-389
# 37 elasticsearch errors processing ec-devco-189
# XML handling error processing ec-devco-no
# 94 elasticsearch errors processing ec-devco-889
# 264 elasticsearch errors processing ec-devco-pk
# 9 elasticsearch errors processing ec-devco-pw
# 78 elasticsearch errors processing ec-devco-ps
# 33 elasticsearch errors processing ec-devco-pa
# 246 elasticsearch errors processing ec-devco-pg
# 140 elasticsearch errors processing ec-devco-py
# 239 elasticsearch errors processing ec-devco-pe
# 249 elasticsearch errors processing ec-devco-ph
# 5 elasticsearch errors processing ec-devco-pn
# XML handling error processing ec-devco-pl
# XML handling error processing ec-devco-ro
# 166 elasticsearch errors processing ec-devco-ru
# 343 elasticsearch errors processing ec-devco-rw
# 11 elasticsearch errors processing ec-devco-pm
# 54 elasticsearch errors processing ec-devco-ws
# 103 elasticsearch errors processing ec-devco-st
# 454 elasticsearch errors processing ec-devco-sn
# 117 elasticsearch errors processing ec-devco-rs
# 2 elasticsearch errors processing ec-devco-cs
# 35 elasticsearch errors processing ec-devco-sc
# 346 elasticsearch errors processing ec-devco-sl
# XML handling error processing ec-devco-sk
# XML handling error processing ec-devco-si
# 85 elasticsearch errors processing ec-devco-sb
# 389 elasticsearch errors processing ec-devco-so
# 21 elasticsearch errors processing ec-devco-689
# 410 elasticsearch errors processing ec-devco-za
# 355 elasticsearch errors processing ec-devco-489
# 58 elasticsearch errors processing ec-devco-679
# XML handling error processing ec-devco-kr
# 106 elasticsearch errors processing ec-devco-ss
# 1538 elasticsearch errors processing ec-devco-289
# XML handling error processing ec-devco-es
# 146 elasticsearch errors processing ec-devco-lk
# 4 elasticsearch errors processing ec-devco-sh
# 57 elasticsearch errors processing ec-devco-kn
# 108 elasticsearch errors processing ec-devco-lc
# 108 elasticsearch errors processing ec-devco-vc
# 3 elasticsearch errors processing ec-devco-88
# 371 elasticsearch errors processing ec-devco-sd
# 71 elasticsearch errors processing ec-devco-sr
# 202 elasticsearch errors processing ec-devco-sz
# XML handling error processing ec-devco-se
# 58 elasticsearch errors processing ec-devco-sy
# XML handling error processing ec-devco-tw
# 245 elasticsearch errors processing ec-devco-tj
# 385 elasticsearch errors processing ec-devco-tz
# 160 elasticsearch errors processing ec-devco-th
# 123 elasticsearch errors processing ec-devco-tl
# Processed 1200 of 4126 files
# 329 elasticsearch errors processing ec-devco-tg
# 41 elasticsearch errors processing ec-devco-to
# ...
# XML handling error processing prefa_1-ug
# 3 elasticsearch errors processing pwyf-998
# XML handling error processing pumpaid-activities
# XML handling error processing saferworld-q1201516
# 28 elasticsearch errors processing saferworld-q1201516
# XML handling error processing saferworld-q2201516
# 28 elasticsearch errors processing saferworld-q2201516
# XML handling error processing saferworld-q3201516
# 32 elasticsearch errors processing saferworld-q3201516
# XML handling error processing saferworld-q4201516
# 35 elasticsearch errors processing saferworld-q4201516
# 2 elasticsearch errors processing rfpap-activities
# XML handling error processing rfuk-298
# 15 elasticsearch errors processing ia_nam-o128
# XML handling error processing nrc-977538313
# 121 elasticsearch errors processing ia_nam-o61
# 2 elasticsearch errors processing ri-uk-activities
# 469 elasticsearch errors processing ocha_fts-republic_of_south_sudan_2015
# XML handling error processing rem-congo
# XML handling error processing rem-cd
# XML handling error processing rem-lr
# XML handling error processing rem-lk
# XML handling error processing restless-in
# XML handling error processing restless-np
# XML handling error processing restless-sl
# XML handling error processing restless-za
# XML handling error processing restless-tz
# XML handling error processing restless-ug
# 3 elasticsearch errors processing restless-gb
# XML handling error processing restless-zm
# XML handling error processing restless-zw
# 84 elasticsearch errors processing afdb-rwanda
# XML handling error processing scuk-scukppa
# 679 elasticsearch errors processing sida-af
# 1516 elasticsearch errors processing sida-298
# XML handling error processing sida-agreements
# 439 elasticsearch errors processing sida-al
# 55 elasticsearch errors processing sida-dz
# 419 elasticsearch errors processing sida-498
# 570 elasticsearch errors processing sida-ao
# 123 elasticsearch errors processing sida-ar
# 216 elasticsearch errors processing sida-am
# 1069 elasticsearch errors processing sida-798
# 66 elasticsearch errors processing sida-az
# 1093 elasticsearch errors processing sida-bd
# 117 elasticsearch errors processing sida-bj
# 21 elasticsearch errors processing sida-bt
# 1097 elasticsearch errors processing sida-bo
# Processed 2200 of 4126 files
# 1015 elasticsearch errors processing sida-ba
# 229 elasticsearch errors processing sida-bw
# 461 elasticsearch errors processing sida-br
# 8 elasticsearch errors processing sida-bg
# 510 elasticsearch errors processing sida-bf
# 290 elasticsearch errors processing sida-bi
# 781 elasticsearch errors processing sida-kh
# 112 elasticsearch errors processing sida-cm
# 28 elasticsearch errors processing sida-cv
# 176 elasticsearch errors processing sida-cf
# 229 elasticsearch errors processing sida-619
# 204 elasticsearch errors processing sida-td
# 218 elasticsearch errors processing sida-cl
# 671 elasticsearch errors processing sida-cn
# 824 elasticsearch errors processing sida-co
# 2 elasticsearch errors processing sida-km
# 736 elasticsearch errors processing sida-cd
# 171 elasticsearch errors processing sida-cg
# XML handling error processing sida-ck
# 271 elasticsearch errors processing sida-cr
# 154 elasticsearch errors processing sida-ci
# 174 elasticsearch errors processing sida-hr
# 27 elasticsearch errors processing sida-cu
# 10 elasticsearch errors processing sida-cz
# 32 elasticsearch errors processing sida-dj
# 2 elasticsearch errors processing sida-dm
# 74 elasticsearch errors processing sida-do
# 223 elasticsearch errors processing sida-ec
# 442 elasticsearch errors processing sida-eg
# 474 elasticsearch errors processing sida-sv
# XML handling error processing sida-gq
# 290 elasticsearch errors processing sida-er
# 203 elasticsearch errors processing sida-ee
# 1380 elasticsearch errors processing sida-et
# 1083 elasticsearch errors processing sida-89
# 28 elasticsearch errors processing sida-789
# 2 elasticsearch errors processing sida-fj
# XML handling error processing sida-ga
# 190 elasticsearch errors processing sida-gm
# 354 elasticsearch errors processing sida-ge
# 227 elasticsearch errors processing sida-gh
# 3 elasticsearch errors processing sida-gd
# 914 elasticsearch errors processing sida-gt
# 78 elasticsearch errors processing sida-gn
# 208 elasticsearch errors processing sida-gw
# 10 elasticsearch errors processing sida-gy
# 168 elasticsearch errors processing sida-ht
# 702 elasticsearch errors processing sida-hn
# 3 elasticsearch errors processing sida-hk
# 17 elasticsearch errors processing sida-hu
# 1176 elasticsearch errors processing sida-in
# 330 elasticsearch errors processing sida-id
# 57 elasticsearch errors processing sida-ir
# 371 elasticsearch errors processing sida-iq
# 2 elasticsearch errors processing sida-il
# 18 elasticsearch errors processing sida-jm
# 169 elasticsearch errors processing sida-jo
# 90 elasticsearch errors processing sida-kz
# 1520 elasticsearch errors processing sida-ke
# 71 elasticsearch errors processing sida-kp
# 4 elasticsearch errors processing sida-kr
# 659 elasticsearch errors processing sida-xk
# XML handling error processing sida-kw
# 137 elasticsearch errors processing sida-kg
# 513 elasticsearch errors processing sida-la
# 243 elasticsearch errors processing sida-lv
# 343 elasticsearch errors processing sida-lb
# 39 elasticsearch errors processing sida-ls
# 470 elasticsearch errors processing sida-lr
# 38 elasticsearch errors processing sida-ly
# 234 elasticsearch errors processing sida-lt
# 421 elasticsearch errors processing sida-mk
# 50 elasticsearch errors processing sida-mg
# 240 elasticsearch errors processing sida-mw
# 58 elasticsearch errors processing sida-my
# 6 elasticsearch errors processing sida-mv
# 561 elasticsearch errors processing sida-ml
# XML handling error processing sida-mh
# 172 elasticsearch errors processing sida-mr
# 19 elasticsearch errors processing sida-mu
# 103 elasticsearch errors processing sida-mx
# 565 elasticsearch errors processing sida-589
# 537 elasticsearch errors processing sida-md
# 146 elasticsearch errors processing sida-mn
# 150 elasticsearch errors processing sida-me
# 78 elasticsearch errors processing sida-ma
# 1764 elasticsearch errors processing sida-mz
# 336 elasticsearch errors processing sida-mm
# 688 elasticsearch errors processing sida-na
# 362 elasticsearch errors processing sida-np
# 1295 elasticsearch errors processing sida-ni
# 103 elasticsearch errors processing sida-ne
# 190 elasticsearch errors processing sida-ng
# 638 elasticsearch errors processing sida-389
# 102 elasticsearch errors processing sida-189
# 19 elasticsearch errors processing sida-889
# 461 elasticsearch errors processing sida-pk
# 1276 elasticsearch errors processing sida-ps
# 19 elasticsearch errors processing sida-pa
# 62 elasticsearch errors processing sida-pg
# Processed 2300 of 4126 files
# 214 elasticsearch errors processing sida-py
# 526 elasticsearch errors processing sida-pe
# 502 elasticsearch errors processing sida-ph
# 120 elasticsearch errors processing sida-pl
# 22 elasticsearch errors processing sida-ro
# 689 elasticsearch errors processing sida-ru
# 606 elasticsearch errors processing sida-rw
# 3 elasticsearch errors processing sida-ws
# 20 elasticsearch errors processing sida-st
# 171 elasticsearch errors processing sida-sn
# 824 elasticsearch errors processing sida-rs
# XML handling error processing sida-sc
# 220 elasticsearch errors processing sida-sl
# 12 elasticsearch errors processing sida-sk
# 6 elasticsearch errors processing sida-si
# 2 elasticsearch errors processing sida-sb
# 539 elasticsearch errors processing sida-so
# 1841 elasticsearch errors processing sida-za
# 238 elasticsearch errors processing sida-489
# 220 elasticsearch errors processing sida-679
# 138 elasticsearch errors processing sida-ss
# 2627 elasticsearch errors processing sida-289
# 970 elasticsearch errors processing sida-lk
# 618 elasticsearch errors processing sida-sd
# 48 elasticsearch errors processing sida-sz
# 140 elasticsearch errors processing sida-sy
# XML handling error processing sida-tw
# 148 elasticsearch errors processing sida-tj
# 2182 elasticsearch errors processing sida-tz
# 446 elasticsearch errors processing sida-th
# 138 elasticsearch errors processing sida-tl
# 249 elasticsearch errors processing sida-tg
# 157 elasticsearch errors processing sida-tn
# 282 elasticsearch errors processing sida-tr
# 3 elasticsearch errors processing sida-tm
# 1315 elasticsearch errors processing sida-ug
# 659 elasticsearch errors processing sida-ua
# 63 elasticsearch errors processing sida-uy
# 74 elasticsearch errors processing sida-uz
# 42 elasticsearch errors processing sida-ve
# 1419 elasticsearch errors processing sida-vn
# 53 elasticsearch errors processing sida-380
# 196 elasticsearch errors processing sida-ye
# 1160 elasticsearch errors processing sida-zm
# 1376 elasticsearch errors processing sida-zw
# 2 elasticsearch errors processing simlab-activities
# 8 elasticsearch errors processing somo-29042016
# XML handling error processing sossaheluk-activities
# 12 elasticsearch errors processing ia_nam-o157
# 5 elasticsearch errors processing nl-kvk-41207989-nl3
# 46 elasticsearch errors processing saferworld-activities
# 19 elasticsearch errors processing ocha_fts-sahel_regional_2014
# 106 elasticsearch errors processing ia_nam-o62
# 2 elasticsearch errors processing spuk-activities
# 30 elasticsearch errors processing afdb-saotome
# XML handling error processing sciaf-cd
# XML handling error processing scottish_government-1213
# 3 elasticsearch errors processing sendacow-998
# XML handling error processing sendacow-bi
# 2 elasticsearch errors processing sendacow-et
# 4 elasticsearch errors processing sendacow-ke
# XML handling error processing sendacow-rw
# XML handling error processing sendacow-ug
# XML handling error processing sacu-activities
# 94 elasticsearch errors processing afdb-senegal
# 49 elasticsearch errors processing ocha_fts-senegal_2014
# 40 elasticsearch errors processing ocha_fts-senegal_2015
# 1582 elasticsearch errors processing aiddata-senamp
# XML handling error processing sense_international-bd
# XML handling error processing sense_international-in
# 34 elasticsearch errors processing afdb-seychelles
# 3127 elasticsearch errors processing sida-998a
# 2786 elasticsearch errors processing sida-998b
# 2958 elasticsearch errors processing sida-998c
# 2751 elasticsearch errors processing sida-998d
# 3638 elasticsearch errors processing sida-998e
# 60 elasticsearch errors processing afdb-sierraleone
# 115 elasticsearch errors processing ss-org-projects
# XML handling error processing signal-activities
# 7 elasticsearch errors processing ia_nam-o64
# 3 elasticsearch errors processing solidaridad-central-america-activity
# 5 elasticsearch errors processing solidaridad-east-and-central-africa-activity
# 10 elasticsearch errors processing solidaridad-netherlands-activity01
# 5 elasticsearch errors processing solidaridad-south-america-activity
# 7 elasticsearch errors processing solidaridad-south-and-south-east-asia-activity
# 2 elasticsearch errors processing solidaridad-southern-africa-activity
# 2 elasticsearch errors processing solidaridad-west-africa-activity
# 40 elasticsearch errors processing ia_nam-o115
# 30 elasticsearch errors processing afdb-somalia
# 476 elasticsearch errors processing ocha_fts-somalia_2012
# Processed 2400 of 4126 files
# 490 elasticsearch errors processing ocha_fts-somalia_2013
# 401 elasticsearch errors processing ocha_fts-somalia_2014
# 308 elasticsearch errors processing ocha_fts-somalia_2015
# 1217 elasticsearch errors processing aiddata-somaliaaims
# 29 elasticsearch errors processing afdb-southafrica
# 6 elasticsearch errors processing afdb-southsudan
# 422 elasticsearch errors processing ocha_fts-southsudan_2012
# 420 elasticsearch errors processing ocha_fts-southsudan_2013
# 608 elasticsearch errors processing ocha_fts-southsudan_2014
# 105 elasticsearch errors processing ocha_fts-south_sudan_refugee_crisis_2014
# XML handling error processing sacbc-activities
# 55 elasticsearch errors processing maec-af
# 186 elasticsearch errors processing maec-298
# 121 elasticsearch errors processing maec-289
# 44 elasticsearch errors processing maec-al
# 221 elasticsearch errors processing maec-389
# 202 elasticsearch errors processing maec-489
# 511 elasticsearch errors processing maec-498
# 146 elasticsearch errors processing maec-ao
# 3 elasticsearch errors processing maec-ag
# 224 elasticsearch errors processing maec-dz
# 530 elasticsearch errors processing maec-ar
# 14 elasticsearch errors processing maec-am
# 7 elasticsearch errors processing maec-619
# 11 elasticsearch errors processing maec-679
# 23 elasticsearch errors processing maec-798
# 4 elasticsearch errors processing maec-789
# 7 elasticsearch errors processing maec-az
# 36 elasticsearch errors processing maec-bd
# 6 elasticsearch errors processing maec-bz
# 110 elasticsearch errors processing maec-bj
# 55 elasticsearch errors processing maec-by
# 1375 elasticsearch errors processing maec-bo
# 76 elasticsearch errors processing maec-ba
# 4 elasticsearch errors processing maec-bw
# 420 elasticsearch errors processing maec-br
# 181 elasticsearch errors processing maec-bf
# 29 elasticsearch errors processing maec-bi
# XML handling error processing maec-bt
# 135 elasticsearch errors processing maec-cv
# 62 elasticsearch errors processing maec-kh
# 211 elasticsearch errors processing maec-cm
# 31 elasticsearch errors processing maec-cf
# 96 elasticsearch errors processing maec-td
# 365 elasticsearch errors processing maec-cl
# 393 elasticsearch errors processing maec-cn
# 1085 elasticsearch errors processing maec-co
# 2 elasticsearch errors processing maec-km
# 51 elasticsearch errors processing maec-cg
# 365 elasticsearch errors processing maec-cd
# 5 elasticsearch errors processing maec-kp
# 146 elasticsearch errors processing maec-ci
# 250 elasticsearch errors processing maec-cr
# 599 elasticsearch errors processing maec-cu
# 2 elasticsearch errors processing maec-dm
# 596 elasticsearch errors processing maec-do
# 918 elasticsearch errors processing maec-ec
# 196 elasticsearch errors processing maec-eg
# 966 elasticsearch errors processing maec-sv
# 14 elasticsearch errors processing maec-er
# 5 elasticsearch errors processing maec-88
# 309 elasticsearch errors processing maec-et
# 200 elasticsearch errors processing maec-89
# 273 elasticsearch errors processing maec-ph
# 11 elasticsearch errors processing maec-ga
# 81 elasticsearch errors processing maec-gm
# 19 elasticsearch errors processing maec-ge
# 125 elasticsearch errors processing maec-gh
# 1115 elasticsearch errors processing maec-gt
# 61 elasticsearch errors processing maec-gn
# 169 elasticsearch errors processing maec-gq
# 135 elasticsearch errors processing maec-gw
# 5 elasticsearch errors processing maec-gy
# 389 elasticsearch errors processing maec-ht
# 578 elasticsearch errors processing maec-hn
# 437 elasticsearch errors processing maec-in
# 92 elasticsearch errors processing maec-id
# 20 elasticsearch errors processing maec-ir
# 30 elasticsearch errors processing maec-iq
# 17 elasticsearch errors processing maec-jm
# 127 elasticsearch errors processing maec-jo
# 16 elasticsearch errors processing maec-kz
# 197 elasticsearch errors processing maec-ke
# 11 elasticsearch errors processing maec-kg
# 11 elasticsearch errors processing maec-57
# 2 elasticsearch errors processing maec-ls
# 117 elasticsearch errors processing maec-lb
# 21 elasticsearch errors processing maec-lr
# 29 elasticsearch errors processing maec-ly
# 20 elasticsearch errors processing maec-mk
# 43 elasticsearch errors processing maec-mg
# 22 elasticsearch errors processing maec-my
# 50 elasticsearch errors processing maec-mw
# 314 elasticsearch errors processing maec-ml
# 955 elasticsearch errors processing maec-ma
# 3 elasticsearch errors processing maec-mu
# 234 elasticsearch errors processing maec-mr
# 637 elasticsearch errors processing maec-mx
# Processed 2500 of 4126 files
# 14 elasticsearch errors processing maec-md
# 9 elasticsearch errors processing maec-mn
# 5 elasticsearch errors processing maec-me
# 498 elasticsearch errors processing maec-mz
# 4 elasticsearch errors processing maec-mm
# 42 elasticsearch errors processing maec-na
# 35 elasticsearch errors processing maec-np
# 1218 elasticsearch errors processing maec-ni
# 154 elasticsearch errors processing maec-ne
# 30 elasticsearch errors processing maec-ng
# 140 elasticsearch errors processing maec-189
# 2 elasticsearch errors processing maec-889
# 75 elasticsearch errors processing maec-589
